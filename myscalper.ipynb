# %%
import pandas as pd
from utils.objects import Point
from utils.enumerations import Trend, Levels
from strategies.bb_strategy import BB_Strategy

# %%
#This function suppress warning messages about pandas using copy-view
pd.options.mode.chained_assignment = None

# %%
candles = pd.read_pickle("V-100/Volatility-100-Index-M1-save-2024-02-16.pkl")
candles
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2024-02-14 22:00:00  2003.16  2005.41  2002.23  2004.43           29
# 1    2024-02-14 22:01:00  2004.86  2007.64  2004.00  2005.64           30
# 2    2024-02-14 22:02:00  2004.90  2007.51  2003.10  2006.16           30
# 3    2024-02-14 22:03:00  2006.12  2008.38  2005.74  2008.38           29
# 4    2024-02-14 22:04:00  2007.58  2008.24  2005.73  2006.27           29
# ...                  ...      ...      ...      ...      ...          ...
# 2876 2024-02-16 21:56:00  1947.45  1948.22  1946.15  1946.63           30
# 2877 2024-02-16 21:57:00  1946.69  1948.01  1945.27  1946.42           30
# 2878 2024-02-16 21:58:00  1946.49  1946.50  1942.46  1944.83           29
# 2879 2024-02-16 21:59:00  1944.14  1946.53  1942.75  1946.23           30
# 2880 2024-02-16 22:00:00  1945.76  1945.76  1943.01  1945.44           29
#
#       spread  real_volume
# 0         45            0
# ...

# %%
symbol = "Volatility 100 Index"

# %%
strategy = BB_Strategy(symbol = symbol)

# %%
data = strategy.test(candles = candles)

# %%
data.set_index("time", inplace = True)
data = data.loc["2024-02-16 00:00:00":]

# %%
data.loc["2024-02-16 14:23:00"]
# Out:
# open             1986.04
# high             1989.02
# low              1985.11
# close            1986.42
# tick_volume           30
# spread                53
# real_volume            0
# rsi             48.82528
# signal_line    50.028437
# base_line      50.789222
# upper_tdi      57.867091
# lower_tdi      44.059246
# cci           -15.218836
# MBL           -14.471553
# dtrade                 -
# Name: 2024-02-16 14:23:00, dtype: object

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2024-02-16 00:00:00  1971.11  1972.67  1970.45  1972.67           30
# 1    2024-02-16 00:01:00  1972.57  1974.10  1970.76  1972.87           29
# 2    2024-02-16 00:02:00  1972.76  1973.25  1970.37  1970.77           30
# 3    2024-02-16 00:03:00  1971.03  1971.40  1969.80  1970.37           29
# 4    2024-02-16 00:04:00  1970.47  1972.71  1969.25  1972.71           30
# ...                  ...      ...      ...      ...      ...          ...
# 1316 2024-02-16 21:56:00  1947.45  1948.22  1946.15  1946.63           30
# 1317 2024-02-16 21:57:00  1946.69  1948.01  1945.27  1946.42           30
# 1318 2024-02-16 21:58:00  1946.49  1946.50  1942.46  1944.83           29
# 1319 2024-02-16 21:59:00  1944.14  1946.53  1942.75  1946.23           30
# 1320 2024-02-16 22:00:00  1945.76  1945.76  1943.01  1945.44           29
#
#       spread  real_volume        rsi  signal_line  base_line  upper_tdi  \
# ...

# %%
signals = data[data["dtrade"] != "-"]
signals
# Out:
#                     time     open     high      low    close  tick_volume  \
# 562  2024-02-16 09:22:00  2028.39  2032.41  2027.50  2032.41           30
# 608  2024-02-16 10:08:00  2007.42  2010.37  2005.94  2010.29           30
# 678  2024-02-16 11:18:00  2034.32  2039.83  2033.65  2039.24           30
# 974  2024-02-16 16:14:00  1949.86  1957.90  1949.86  1957.04           30
# 1043 2024-02-16 17:23:00  1965.91  1971.27  1965.12  1971.27           30
# 1177 2024-02-16 19:37:00  1963.50  1969.50  1961.74  1968.58           30
# 1279 2024-02-16 21:19:00  1958.25  1960.00  1958.16  1958.77           30
#
#       spread  real_volume        rsi  signal_line  base_line  upper_tdi  \
# 562       45            0  63.290390    59.249637  58.114478  64.215396
# 608       45            0  50.054372    45.543089  42.245031  51.909491
# 678       45            0  57.902908    55.693496  59.135611  69.084509
# 974       53            0  50.705145    48.815003  45.303668  57.241442
# ...

# %%
pd.to_pickle(data, "SIGNALS/V-100-signals-16.pkl")

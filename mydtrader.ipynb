# %%
import pandas as pd
from utils.objects import Point
from utils.enumerations import Trend, Levels
from strategies.tt_strategy import TT_Strategy

# %%
#This function suppress warning messages about pandas using copy-view
pd.options.mode.chained_assignment = None

# %%
candles = pd.read_pickle("V-100/Volatility-100-Index-M1-save-2024-02-11.pkl")
candles
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2024-02-09 22:00:00  1742.82  1745.84  1742.43  1743.94           30
# 1    2024-02-09 22:01:00  1743.75  1746.28  1742.93  1746.28           30
# 2    2024-02-09 22:02:00  1745.89  1746.12  1743.29  1744.39           30
# 3    2024-02-09 22:03:00  1744.55  1748.88  1744.39  1748.46           30
# 4    2024-02-09 22:04:00  1748.10  1749.31  1746.65  1746.75           30
# ...                  ...      ...      ...      ...      ...          ...
# 2876 2024-02-11 21:56:00  1817.65  1819.74  1816.63  1818.53           30
# 2877 2024-02-11 21:57:00  1818.04  1819.97  1816.13  1819.07           30
# 2878 2024-02-11 21:58:00  1819.56  1822.62  1818.71  1820.97           30
# 2879 2024-02-11 21:59:00  1820.43  1821.39  1819.69  1821.32           30
# 2880 2024-02-11 22:00:00  1821.00  1821.00  1818.20  1819.61           29
#
#       spread  real_volume
# 0         42            0
# ...

# %%
symbol = "Volatility 100 Index"

# %%
strategy = TT_Strategy(symbol = symbol)

# %%
data = strategy.test(candles = candles)
# Out:
# Setups: 91

# %%
data.set_index("time", inplace = True)
data = data.loc["2024-02-11 00:00:00":]
data.reset_index(inplace = True)

# %%
data
# Out:
#                     time     open     high      low    close  tick_volume  \
# 0    2024-02-11 00:00:00  1749.12  1751.06  1748.31  1749.83           30
# 1    2024-02-11 00:01:00  1750.27  1752.41  1749.49  1751.22           30
# 2    2024-02-11 00:02:00  1751.32  1753.53  1749.77  1753.53           29
# 3    2024-02-11 00:03:00  1753.14  1756.16  1752.23  1756.05           30
# 4    2024-02-11 00:04:00  1755.83  1756.88  1754.88  1755.97           30
# ...                  ...      ...      ...      ...      ...          ...
# 1316 2024-02-11 21:56:00  1817.65  1819.74  1816.63  1818.53           30
# 1317 2024-02-11 21:57:00  1818.04  1819.97  1816.13  1819.07           30
# 1318 2024-02-11 21:58:00  1819.56  1822.62  1818.71  1820.97           30
# 1319 2024-02-11 21:59:00  1820.43  1821.39  1819.69  1821.32           30
# 1320 2024-02-11 22:00:00  1821.00  1821.00  1818.20  1819.61           29
#
#       spread  real_volume        EMA_5  Delta-5  ...  13/50-cross  5/13-cross  \
# ...

# %%
signals = data[data["dtrade"] != "-"]
signals
# Out:
#                     time     open     high      low    close  tick_volume  \
# 14   2024-02-11 00:14:00  1742.36  1745.33  1742.36  1745.15           30
# 58   2024-02-11 00:58:00  1733.86  1743.81  1733.86  1743.20           30
# 117  2024-02-11 01:57:00  1739.45  1741.87  1738.78  1741.87           30
# 236  2024-02-11 03:56:00  1744.33  1747.07  1743.09  1747.07           29
# 508  2024-02-11 08:28:00  1690.65  1696.16  1690.05  1695.58           30
# 592  2024-02-11 09:52:00  1684.06  1688.35  1683.86  1688.35           30
# 671  2024-02-11 11:11:00  1713.07  1721.73  1713.07  1721.73           29
# 728  2024-02-11 12:08:00  1725.90  1730.28  1724.85  1729.71           30
# 909  2024-02-11 15:09:00  1836.31  1840.67  1835.91  1840.67           30
# 1055 2024-02-11 17:35:00  1825.55  1829.80  1825.35  1828.16           30
# 1242 2024-02-11 20:42:00  1823.57  1826.71  1823.57  1826.27           30
#
#       spread  real_volume        EMA_5  Delta-5  ...  13/50-cross  5/13-cross  \
# ...

# %%
pd.to_pickle(data, "SIGNALS/V-100-signals-11.pkl")
